# %%
import pickle
import numpy as np
import fun_dual as f
from itertools import product,permutations

# %% [markdown]
# # Print solution Y^(a,k), C, Q

# %%
n,K,d=8,9,3

with open("inf_cert_8", 'rb') as inf_cert:
    Y,C=pickle.load(inf_cert)
    Q=np.zeros(n+1)

y=f.yijtp_fun(Y,n)

f4,_=f.f4_fun(n)

f2M,_=f.f2M_fun(n)

D=f.D_fun(C,n,d)

for a in range(n+1):
    for k in range(a,int((n+a)/2)+1):
        
        print("Y^(%s,%s)=%s\n" % (a,k,Y[f2M[a,k]]))
        
print("C=%s\n" % (C))
print("D=%s\n" % (D))
print("Q=%s\n" % (Q))
# Out:
# Y^(0,0)=[[ 203.  -65.  -54.  104.   87.   40. -208. -245.  567.]
#  [ -65.  103.    4.  -43.  -41.    4.   63.   99.  -39.]
#  [ -54.    4.   45.  -51.  -32.   -4.   58.   44. -265.]
#  [ 104.  -43.  -51.   90.   53.    8. -109. -109.  364.]
#  [  87.  -41.  -32.   53.   69.  -15.  -86. -121.  137.]
#  [  40.    4.   -4.    8.  -15.   75.  -43.  -41.  198.]
#  [-208.   63.   58. -109.  -86.  -43.  215.  244. -616.]
#  [-245.   99.   44. -109. -121.  -41.  244.  342. -473.]
#  [ 567.  -39. -265.  364.  137.  198. -616. -473. 2934.]]
#
# Y^(0,1)=[[2984. -426. -163. -254.  356. 1048. 1524.]
#  [-426.  732. -407.  -25.   76. -576. -888.]
#  [-163. -407.  607.   46. -190.   91.  105.]
#  [-254.  -25.   46.  174. -169. -239. -292.]
#  [ 356.   76. -190. -169.  497.  282.  239.]
#  [1048. -576.   91. -239.  282. 1406. 2364.]
#  [1524. -888.  105. -292.  239. 2364. 5048.]]
#
# Y^(0,2)=[[ 6808.  1459.   116.   -28. -1411.]
#  [ 1459.  3525. -1235.  -878.  1003.]
#  [  116. -1235.  1091.   380.  -285.]
#  [  -28.  -878.   380.  1121.   572.]
#  [-1411.  1003.  -285.   572. 13044.]]
#
# Y^(0,3)=[[9202. 2132. 1005.]
#  [2132. 8388.  -63.]
#  [1005.  -63. 3225.]]
#
# Y^(0,4)=[[4397.70903679]]
#
# Y^(1,1)=[[ 3.80100000e+03 -1.12878177e+01 -5.26000000e+02  9.00000000e+00
#   -2.87000000e+02 -1.06400000e+03 -2.39000000e+03  2.36700000e+03]
#  [-1.12878177e+01  2.56000000e+02 -1.73000000e+02 -1.76000000e+02
#   -1.10000000e+01  8.50000000e+01  2.21000000e+02 -2.94000000e+02]
#  [-5.26000000e+02 -1.73000000e+02  3.43000000e+02  4.60000000e+01
#    1.50000000e+01  6.80000000e+01  1.90000000e+02 -5.33000000e+02]
#  [ 9.00000000e+00 -1.76000000e+02  4.60000000e+01  2.92000000e+02
#   -5.60000000e+01  2.10000000e+01 -8.20000000e+01  1.17300000e+03]
#  [-2.87000000e+02 -1.10000000e+01  1.50000000e+01 -5.60000000e+01
#    2.56000000e+02  1.46000000e+02  3.48000000e+02 -7.91000000e+02]
#  [-1.06400000e+03  8.50000000e+01  6.80000000e+01  2.10000000e+01
#    1.46000000e+02  6.16000000e+02  1.29300000e+03 -7.15000000e+02]
#  [-2.39000000e+03  2.21000000e+02  1.90000000e+02 -8.20000000e+01
#    3.48000000e+02  1.29300000e+03  2.84600000e+03 -2.30000000e+03]
#  [ 2.36700000e+03 -2.94000000e+02 -5.33000000e+02  1.17300000e+03
#   -7.91000000e+02 -7.15000000e+02 -2.30000000e+03  9.18600000e+03]]
#
# Y^(1,2)=[[29824.  8270.  7252.  4833. 16020. 17811.]
#  [ 8270. 15415.  4106.   601.  -214.  3589.]
#  [ 7252.  4106.  6360.  1394.  1364.  4726.]
#  [ 4833.   601.  1394.  1307.  2458.  3038.]
#  [16020.  -214.  1364.  2458. 12542.  9516.]
#  [17811.  3589.  4726.  3038.  9516. 11940.]]
#
# Y^(1,3)=[[ 6.7670e+03 -1.1420e+03  1.3400e+02  2.0000e+00]
#  [-1.1420e+03  1.1865e+04  4.2800e+02  7.4100e+02]
#  [ 1.3400e+02  4.2800e+02  3.9020e+03 -5.0000e+00]
#  [ 2.0000e+00  7.4100e+02 -5.0000e+00  8.2000e+01]]
#
# Y^(1,4)=[[3793.  521.]
#  [ 521. 3504.]]
#
# Y^(2,2)=[[13392.          1175.5720798  -3027.86666667 -2055.
#   -5540.         -7034.           535.        ]
#  [ 1175.5720798   1013.29318634  -364.87525584  -316.
#    -542.          -770.           370.        ]
#  [-3027.86666667  -364.87525584  1413.           410.
#     859.          1653.         -2157.        ]
#  [-2055.          -316.           410.           954.
#     912.          1020.            21.        ]
#  [-5540.          -542.           859.           912.
#    2737.          3180.           733.        ]
#  [-7034.          -770.          1653.          1020.
#    3180.          4509.          -368.        ]
#  [  535.           370.         -2157.            21.
#     733.          -368.          7924.        ]]
#
# Y^(2,3)=[[ 8.65100000e+03  5.29937030e+03  5.10000000e+02  8.00000000e+00
#   -7.69000000e+02]
#  [ 5.29937030e+03  1.57649539e+04  2.21100000e+03 -5.77000000e+02
#   -1.99000000e+03]
#  [ 5.10000000e+02  2.21100000e+03  2.49800000e+03 -1.62000000e+02
#   -5.99000000e+02]
#  [ 8.00000000e+00 -5.77000000e+02 -1.62000000e+02  7.10000000e+01
#    5.70000000e+01]
#  [-7.69000000e+02 -1.99000000e+03 -5.99000000e+02  5.70000000e+01
#    6.90000000e+02]]
#
# Y^(2,4)=[[3265.19277592   57.          276.        ]
#  [  57.         1793.          -84.        ]
#  [ 276.          -84.          199.        ]]
#
# Y^(2,5)=[[3465.36640681]]
#
# Y^(3,3)=[[ 4.52592492e+03 -4.45428203e+02 -6.02341179e+02 -9.47264069e+01
#   -1.75000000e+02 -9.18000000e+02]
#  [-4.45428203e+02  1.30953152e+03 -6.50974592e+01  3.91776266e+01
#    7.20000000e+01  5.15339611e+02]
#  [-6.02341179e+02 -6.50974592e+01  1.26633139e+03  6.44977039e+00
#   -5.10000000e+01  1.77538668e+02]
#  [-9.47264069e+01  3.91776266e+01  6.44977039e+00  1.17025021e+01
#   -3.00000000e+00  4.03133448e+01]
#  [-1.75000000e+02  7.20000000e+01 -5.10000000e+01 -3.00000000e+00
#    3.70000000e+02  4.36710920e+02]
#  [-9.18000000e+02  5.15339611e+02  1.77538668e+02  4.03133448e+01
#    4.36710920e+02  4.59552907e+03]]
#
# Y^(3,4)=[[5318.04002141 1736.26519136  -94.40056276   80.52888243]
#  [1736.26519136 2194.308602   -203.12604634 -622.53289727]
#  [ -94.40056276 -203.12604634   62.94955961  123.43408358]
#  [  80.52888243 -622.53289727  123.43408358 1239.91866183]]
#
# Y^(3,5)=[[3756.82299071  173.95586857]
#  [ 173.95586857  169.62229335]]
#
# Y^(4,4)=[[ 2840.01688295 -1521.90998886   -87.18785173   397.87039308
#    -696.38872098]
#  [-1521.90998886  1945.48802973   145.951802    -102.06469381
#     297.38286824]
#  [  -87.18785173   145.951802      32.28948391    12.59745687
#     194.61036082]
#  [  397.87039308  -102.06469381    12.59745687   140.08091517
#    -148.72736462]
#  [ -696.38872098   297.38286824   194.61036082  -148.72736462
#    6511.24325015]]
#
# Y^(4,5)=[[2900.99183856  521.90641382 -104.30477491]
#  [ 521.90641382  294.62071643 -329.09510739]
#  [-104.30477491 -329.09510739 3512.77248873]]
#
# Y^(4,6)=[[47.50452937]]
#
# Y^(5,5)=[[3271.2615007  -178.66954213 -313.02882631  735.41125636]
#  [-178.66954213   65.32612817  -11.58129263  268.54251082]
#  [-313.02882631  -11.58129263  536.8910729    22.10557914]
#  [ 735.41125636  268.54251082   22.10557914 5969.75864952]]
#
# Y^(5,6)=[[327.64954493 -16.61153391]
#  [-16.61153391   0.84323592]]
#
# Y^(6,6)=[[ 217.29234501   28.24594793  315.57685411]
#  [  28.24594793  368.04145602 -474.15217569]
#  [ 315.57685411 -474.15217569 4205.81038386]]
#
# Y^(6,7)=[[430.04599394]]
#
# Y^(7,7)=[[ 153.79612655  132.59463212]
#  [ 132.59463212 5558.43621072]]
#
# Y^(8,8)=[[2496.73843514]]
#
# C=[ 3.08e+02]
# [ 1.20e+02]
# [ 4.52e+01]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
# [ 0.00e+00]
#
#
# D=[56.93309538538275, 40.23381767033892, 26.357860033871788, 15.305222475981353, 7.075904996667613, 1.66990759593057, -0.912769726229776, -0.6721269698134247, 2.3918358651796234]
#
# Q=[0. 0. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# # Objective value

# %%
obj_val = (K*D[0]-C[0])+(2**n/K-1)*Q[0] - y[f4[0, 0, 0, 0]]

print("obj_val=%s" % obj_val)
# Out:
# obj_val=0.989453296541484

# %% [markdown]
# # Constraints

# %%
#### Structure constraints ####

const=[]

for i, j, t, p in f4.keys():

    if (t - p) % 2 == 0 and not i==0 and not j == 0 and not i == j == t == p:

        zero = sum([y[f4[a, b, c, q]] + Q[a+b-c-q]
                    for a, b, c, q in f4.keys() if t - p == c - q and (i, j, i + j - t - p) in 
                    list(permutations((a, b, a + b - c - q)))])

        const.append(abs(zero))


print("Structure constraints = %s" % max(const))

const=[]

for i in range(1, d):
    zero = K*D[i]-C[i] +(2**n/K-2)*Q[i]-Q[0] - y[f4[i, i, i, i]] - 2*y[f4[i, 0, 0, 0]]

    const.append(abs(zero))

print("Knill Lafllame 1 = %s" % max(const))

const=[]

for i in range(d, n+1):
    zero = K*D[i] +(2**n/K-2)*Q[i]-Q[0] - y[f4[i, i, i, i]] - 2*y[f4[i, 0, 0, 0]]
    const.append(abs(zero))
        
print("Knill Lafllame 2 = %s" % max(const))
# Out:
# Structure constraints = 8.526512829121202e-14
# Knill Lafllame 1 = 4.263256414560601e-14
# Knill Lafllame 2 = 1.4210854715202004e-14

# %% [markdown]
# # Minimal eigenvalue

# %%
ref = np.infty
for i in range(len(Y)):
    min_eig = min(np.linalg.eigvals(Y[i].astype('float')))
    if ref >= min_eig:
        ref = min_eig

print("Min eigenvalue = %s" % ref)
# Out:
# Min eigenvalue = 0.0010435795312035237
