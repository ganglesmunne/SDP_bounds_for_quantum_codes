# %%
import pickle
import numpy as np
import fun_dual as f
from itertools import permutations
from sympy import Matrix
from IPython.display import display

# %% [markdown]
# # Print solution $Y^{(a,k)}$, $C_i$ and $Q_i$ of the SDP from Eq. (150)

# %%
n,K,d=8,9,3

with open("inf_cert_8", 'rb') as inf_cert:
    Y,C=pickle.load(inf_cert)
    Q=np.zeros(n+1)

y=f.yijtp_fun(Y,n)

f4,_=f.f4_fun(n)

f2M,_=f.f2M_fun(n)

D=f.D_fun(C,n,d)

for a in range(n+1):
    for k in range(a,int((n+a)/2)+1):
        print("Y^(%s,%s)=" % (a,k))
        display(Matrix((Y[f2M[a,k]])))
        
print("C=")
display(Matrix(C))
print("Q=")
display(Matrix(Q))
# Out:
# Y^(0,0)=
# Matrix([
# [ 203.0,            -65.0,            -54.0,  104.0,   87.0,  40.0, -208.0, -245.0,  567.0],
# [ -65.0,            103.0, 4.00000000000001,  -43.0,  -41.0,   4.0,   63.0,   99.0,  -39.0],
# [ -54.0, 4.00000000000001,             45.0,  -51.0,  -32.0,  -4.0,   58.0,   44.0, -265.0],
# [ 104.0,            -43.0,            -51.0,   90.0,   53.0,   8.0, -109.0, -109.0,  364.0],
# [  87.0,            -41.0,            -32.0,   53.0,   69.0, -15.0,  -86.0, -121.0,  137.0],
# [  40.0,              4.0,             -4.0,    8.0,  -15.0,  75.0,  -43.0,  -41.0,  198.0],
# [-208.0,             63.0,             58.0, -109.0,  -86.0, -43.0,  215.0,  244.0, -616.0],
# [-245.0,             99.0,             44.0, -109.0, -121.0, -41.0,  244.0,  342.0, -473.0],
# [ 567.0,            -39.0,           -265.0,  364.0,  137.0, 198.0, -616.0, -473.0, 2934.0]])
# Y^(0,1)=
# Matrix([
# [2984.0, -426.0, -163.0, -254.0,  356.0, 1048.0, 1524.0],
# [-426.0,  732.0, -407.0,  -25.0,   76.0, -576.0, -888.0],
# [-163.0, -407.0,  607.0,   46.0, -190.0,   91.0,  105.0],
# [-254.0,  -25.0,   46.0,  174.0, -169.0, -239.0, -292.0],
# [ 356.0,   76.0, -190.0, -169.0,  497.0,  282.0,  239.0],
# [1048.0, -576.0,   91.0, -239.0,  282.0, 1406.0, 2364.0],
# [1524.0, -888.0,  105.0, -292.0,  239.0, 2364.0, 5048.0]])
# Y^(0,2)=
# Matrix([
# [ 6808.0,  1459.0,   116.0,  -28.0, -1411.0],
# [ 1459.0,  3525.0, -1235.0, -878.0,  1003.0],
# [  116.0, -1235.0,  1091.0,  380.0,  -285.0],
# [  -28.0,  -878.0,   380.0, 1121.0,   572.0],
# [-1411.0,  1003.0,  -285.0,  572.0, 13044.0]])
# Y^(0,3)=
# Matrix([
# [9202.0, 2132.0, 1005.0],
# [2132.0, 8388.0,  -63.0],
# [1005.0,  -63.0, 3225.0]])
# Y^(0,4)=
# Matrix([[4397.70903678948]])
# Y^(1,1)=
# Matrix([
# [           3801.0, -11.2878177336968, -526.0,    9.0, -287.0, -1064.0, -2390.0,  2367.0],
# [-11.2878177336968,             256.0, -173.0, -176.0,  -11.0,    85.0,   221.0,  -294.0],
# [           -526.0,            -173.0,  343.0,   46.0,   15.0,    68.0,   190.0,  -533.0],
# [              9.0,            -176.0,   46.0,  292.0,  -56.0,    21.0,   -82.0,  1173.0],
# [           -287.0,             -11.0,   15.0,  -56.0,  256.0,   146.0,   348.0,  -791.0],
# [          -1064.0,              85.0,   68.0,   21.0,  146.0,   616.0,  1293.0,  -715.0],
# [          -2390.0,             221.0,  190.0,  -82.0,  348.0,  1293.0,  2846.0, -2300.0],
# [           2367.0,            -294.0, -533.0, 1173.0, -791.0,  -715.0, -2300.0,  9186.0]])
# Y^(1,2)=
# Matrix([
# [29824.0,  8270.0, 7252.0, 4833.0, 16020.0, 17811.0],
# [ 8270.0, 15415.0, 4106.0,  601.0,  -214.0,  3589.0],
# [ 7252.0,  4106.0, 6360.0, 1394.0,  1364.0,  4726.0],
# [ 4833.0,   601.0, 1394.0, 1307.0,  2458.0,  3038.0],
# [16020.0,  -214.0, 1364.0, 2458.0, 12542.0,  9516.0],
# [17811.0,  3589.0, 4726.0, 3038.0,  9516.0, 11940.0]])
# Y^(1,3)=
# Matrix([
# [ 6767.0, -1142.0,  134.0,   2.0],
# [-1142.0, 11865.0,  428.0, 741.0],
# [  134.0,   428.0, 3902.0,  -5.0],
# [    2.0,   741.0,   -5.0,  82.0]])
# Y^(1,4)=
# Matrix([
# [3793.0,  521.0],
# [ 521.0, 3504.0]])
# Y^(2,2)=
# Matrix([
# [          13392.0,  1175.57207979821, -3027.86666666667, -2055.0, -5540.0, -7034.0,   535.0],
# [ 1175.57207979821,  1013.29318633823, -364.875255835633,  -316.0,  -542.0,  -770.0,   370.0],
# [-3027.86666666667, -364.875255835633,            1413.0,   410.0,   859.0,  1653.0, -2157.0],
# [          -2055.0,            -316.0,             410.0,   954.0,   912.0,  1020.0,    21.0],
# [          -5540.0,            -542.0,             859.0,   912.0,  2737.0,  3180.0,   733.0],
# [          -7034.0,            -770.0,            1653.0,  1020.0,  3180.0,  4509.0,  -368.0],
# [            535.0,             370.0,           -2157.0,    21.0,   733.0,  -368.0,  7924.0]])
# Y^(2,3)=
# Matrix([
# [          8651.0, 5299.37029612119,  510.0,    8.0,  -769.0],
# [5299.37029612119, 15764.9539163882, 2211.0, -577.0, -1990.0],
# [           510.0,           2211.0, 2498.0, -162.0,  -599.0],
# [             8.0,           -577.0, -162.0,   71.0,    57.0],
# [          -769.0,          -1990.0, -599.0,   57.0,   690.0]])
# Y^(2,4)=
# Matrix([
# [3265.19277592115,   57.0, 276.0],
# [            57.0, 1793.0, -84.0],
# [           276.0,  -84.0, 199.0]])
# Y^(2,5)=
# Matrix([[3465.36640681408]])
# Y^(3,3)=
# Matrix([
# [ 4525.92491543799, -445.428202709125, -602.341178708938, -94.7264069347513,           -175.0,           -918.0],
# [-445.428202709125,  1309.53151946529, -65.0974591613193,  39.1776266221062,             72.0, 515.339611086087],
# [-602.341178708938, -65.0974591613193,  1266.33138659522,  6.44977039092803,            -51.0, 177.538668051121],
# [-94.7264069347513,  39.1776266221062,  6.44977039092803,  11.7025021435797,             -3.0, 40.3133448484412],
# [           -175.0,              72.0,             -51.0,              -3.0,            370.0, 436.710920228668],
# [           -918.0,  515.339611086087,  177.538668051121,  40.3133448484412, 436.710920228668, 4595.52907360409]])
# Y^(3,4)=
# Matrix([
# [ 5318.04002141087,  1736.26519135859, -94.4005627649116,  80.5288824251686],
# [ 1736.26519135859,   2194.3086019964, -203.126046340825, -622.532897269685],
# [-94.4005627649116, -203.126046340825,  62.9495596103014,  123.434083580811],
# [ 80.5288824251686, -622.532897269685,  123.434083580811,  1239.91866183191]])
# Y^(3,5)=
# Matrix([
# [  3756.822990709, 173.955868574497],
# [173.955868574497, 169.622293354356]])
# Y^(4,4)=
# Matrix([
# [ 2840.01688294763, -1521.90998886152, -87.1878517280768,  397.870393079418, -696.388720983097],
# [-1521.90998886152,  1945.48802972896,   145.95180200491, -102.064693814877,  297.382868242894],
# [-87.1878517280768,   145.95180200491,  32.2894839137347,  12.5974568686128,  194.610360823065],
# [ 397.870393079418, -102.064693814877,  12.5974568686128,  140.080915167993, -148.727364624317],
# [-696.388720983097,  297.382868242894,  194.610360823065, -148.727364624317,  6511.24325014587]])
# Y^(4,5)=
# Matrix([
# [  2900.9918385562,  521.906413823037, -104.304774908057],
# [ 521.906413823037,  294.620716427562, -329.095107387041],
# [-104.304774908057, -329.095107387041,  3512.77248872799]])
# Y^(4,6)=
# Matrix([[47.5045293728008]])
# Y^(5,5)=
# Matrix([
# [ 3271.26150069508, -178.669542126227, -313.028826310514, 735.411256355374],
# [-178.669542126227,  65.3261281688741, -11.5812926278167, 268.542510822329],
# [-313.028826310514, -11.5812926278167,  536.891072898172, 22.1055791378777],
# [ 735.411256355374,  268.542510822329,  22.1055791378777, 5969.75864952009]])
# Y^(5,6)=
# Matrix([
# [ 327.649544934165, -16.6115339101076],
# [-16.6115339101076, 0.843235921952408]])
# Y^(6,6)=
# Matrix([
# [ 217.29234500829,  28.2459479298575,  315.576854110208],
# [28.2459479298575,  368.041456022194, -474.152175694632],
# [315.576854110208, -474.152175694632,  4205.81038386396]])
# Y^(6,7)=
# Matrix([[430.045993943946]])
# Y^(7,7)=
# Matrix([
# [153.796126552178, 132.594632120839],
# [132.594632120839, 5558.43621071867]])
# Y^(8,8)=
# Matrix([[2496.73843513887]])
# C=
# Matrix([
# [308.408405171903],
# [120.118227361035],
# [45.1731212572272],
# [               0],
# [               0],
# [               0],
# [               0],
# [               0],
# [               0]])
# Q=
# Matrix([
# [0],
# [0],
# [0],
# [0],
# [0],
# [0],
# [0],
# [0],
# [0]])

# %% [markdown]
# # Objective value

# %%
obj_val = (K*D[0]-C[0])+(2**n/K-1)*Q[0] - y[f4[0, 0, 0, 0]]

print("obj_val=%s" % obj_val)
# Out:
# obj_val=0.989453296541484

# %% [markdown]
# # Maximum violation constraints

# %%
const=[]

for i, j, t, p in f4.keys():

    if (t - p) % 2 == 0 and not i==0 and not j == 0 and not i == j == t == p:

        zero = sum([y[f4[a, b, c, q]] + Q[a+b-c-q]
                    for a, b, c, q in f4.keys() if t - p == c - q and (i, j, i + j - t - p) in 
                    list(permutations((a, b, a + b - c - q)))])

        const.append(abs(zero))


print("Structure constraints = %s" % max(const))

const=[]

for i in range(1, d):
    zero = K*D[i]-C[i] +(2**n/K-2)*Q[i]-Q[0] - y[f4[i, i, i, i]] - 2*y[f4[i, 0, 0, 0]]

    const.append(abs(zero))

print("Other constraints 1 = %s" % max(const))

const=[]

for i in range(d, n+1):
    zero = K*D[i] +(2**n/K-2)*Q[i]-Q[0] - y[f4[i, i, i, i]] - 2*y[f4[i, 0, 0, 0]]
    const.append(abs(zero))
        
print("Other constraint 2 = %s" % max(const))
# Out:
# Structure constraints = 8.526512829121202e-14
# Other constraints 1 = 4.263256414560601e-14
# Other constraint 2 = 1.4210854715202004e-14

# %% [markdown]
# # Minimum eigenvalue

# %%
ref = np.infty
for i in range(len(Y)):
    min_eig = min(np.linalg.eigvals(Y[i].astype('float')))
    if ref >= min_eig:
        ref = min_eig

print("Minimum eigenvalue = %s" % ref)
# Out:
# Minimum eigenvalue = 0.0010435795312035237
